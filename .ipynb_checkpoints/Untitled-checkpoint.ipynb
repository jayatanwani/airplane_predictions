# %%
import graphviz

import os


graphviz_path = "C:\\Program Files (x86)\\Graphviz2.38\\bin"
os.environ["PATH"] += os.pathsep + graphviz_path

# %%
g = graphviz.Source.from_file("airplane_analysis.dot")

# %%
""
